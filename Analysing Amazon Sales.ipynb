# %% [markdown]
# # Analysing Amazon Sales

# %%
import pandas as pd

# %%
data1=pd.read_csv('Amazon Sale Report.csv')
# Out:
# C:\Users\233662\AppData\Local\Temp\ipykernel_4904\4015051764.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1=pd.read_csv('Amazon Sale Report.csv')

# %%
data1
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
data1.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
data1.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128970  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU  \
# 128970      Amazon.in          Expedited  JNE3697   JNE3697-KR-XL
# 128971      Amazon.in          Expedited   SET401  SET401-KR-NP-M
# 128972      Amazon.in          Expedited    J0157    J0157-DR-XXL
# 128973      Amazon.in          Expedited    J0012    J0012-SKD-XS
# 128974      Amazon.in          Expedited    J0003     J0003-SET-S
#
#              Category  ... currency  Amount  ship-city    ship-state  \
# 128970          kurta  ...      INR   517.0  HYDERABAD     TELANGANA
# ...

# %%
data1.shape
# Out:
# (128975, 24)

# %%
data1.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
data1.info
# Out:
# <bound method DataFrame.info of          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
data1.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
data1.dropna(inplace=True)

# %%
data1.shape
# Out:
# (19379, 24)

# %%
data1.describe()
# Out:
#                index           Qty        Amount  ship-postal-code
# count   19379.000000  19379.000000  19379.000000      19379.000000
# mean    86650.405542      1.004799    673.245162     464618.933743
# std     22204.535858      0.082081    287.866514     191536.937504
# min     49051.000000      1.000000      0.000000     110001.000000
# 25%     67813.000000      1.000000    471.000000     380058.000000
# 50%     83317.000000      1.000000    678.000000     500032.000000
# 75%    105153.500000      1.000000    786.000000     600039.000000
# max    128891.000000      5.000000   2796.000000     855107.000000

# %%
data1['Category'].unique()
# Out:
# array(['kurta', 'Top', 'Western Dress', 'Set', 'Ethnic Dress', 'Bottom',
#        'Blouse', 'Saree'], dtype=object)

# %%
Sort_data1=data1.sort_values(by=['Amount'],ascending=False)
Sort_data1
# Out:
#          index             Order ID      Date                        Status  \
# 79899    79899  405-6877720-7865168  05-07-22  Shipped - Returned to Seller
# 56307    56307  405-5657207-4685151  05-26-22  Shipped - Delivered to Buyer
# 67764    67764  402-0603541-4663511  05-16-22  Shipped - Delivered to Buyer
# 126821  126821  403-2726196-9752350  06-02-22  Shipped - Delivered to Buyer
# 69527    69527  406-0207843-8044301  05-15-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 119631  119631  408-0843279-7773906  06-07-22  Shipped - Delivered to Buyer
# 75145    75145  408-1099068-5253924  05-10-22  Shipped - Delivered to Buyer
# 127248  127248  408-3500040-5756334  06-02-22  Shipped - Delivered to Buyer
# 76946    76946  408-0914949-2103564  05-09-22  Shipped - Delivered to Buyer
# 72688    72688  408-9319408-2730733  05-12-22  Shipped - Delivered to Buyer
#
# ...

# %%
Sort_data1=data1.sort_values(by=['Amount'],ascending=True)
Sort_data1
# Out:
#          index             Order ID      Date                        Status  \
# 93303    93303  408-2946294-1219548  06-27-22           Shipped - Picked Up
# 60854    60854  408-6142481-5250727  05-22-22  Shipped - Delivered to Buyer
# 69176    69176  408-8641450-9868358  05-15-22  Shipped - Delivered to Buyer
# 105439  105439  408-5729132-7869116  06-17-22  Shipped - Delivered to Buyer
# 88809    88809  408-9723096-6073963  05-02-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 126821  126821  403-2726196-9752350  06-02-22  Shipped - Delivered to Buyer
# 56307    56307  405-5657207-4685151  05-26-22  Shipped - Delivered to Buyer
# 67764    67764  402-0603541-4663511  05-16-22  Shipped - Delivered to Buyer
# 69527    69527  406-0207843-8044301  05-15-22  Shipped - Delivered to Buyer
# 79899    79899  405-6877720-7865168  05-07-22  Shipped - Returned to Seller
#
# ...

# %%
spec=Sort_data1[['Order ID','Date','Status','Amount']]
spec
# Out:
#                    Order ID      Date                        Status  Amount
# 93303   408-2946294-1219548  06-27-22           Shipped - Picked Up     0.0
# 60854   408-6142481-5250727  05-22-22  Shipped - Delivered to Buyer     0.0
# 69176   408-8641450-9868358  05-15-22  Shipped - Delivered to Buyer     0.0
# 105439  408-5729132-7869116  06-17-22  Shipped - Delivered to Buyer     0.0
# 88809   408-9723096-6073963  05-02-22  Shipped - Delivered to Buyer     0.0
# ...                     ...       ...                           ...     ...
# 126821  403-2726196-9752350  06-02-22  Shipped - Delivered to Buyer  2598.0
# 56307   405-5657207-4685151  05-26-22  Shipped - Delivered to Buyer  2598.0
# 67764   402-0603541-4663511  05-16-22  Shipped - Delivered to Buyer  2598.0
# 69527   406-0207843-8044301  05-15-22  Shipped - Delivered to Buyer  2598.0
# 79899   405-6877720-7865168  05-07-22  Shipped - Returned to Seller  2796.0
#
# [19379 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.distplot(data1['Amount'])
# Out:
# C:\Users\233662\AppData\Local\Temp\ipykernel_4904\58020744.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['Amount'])
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
sns.distplot(data1["ship-postal-code"])
# Out:
# C:\Users\233662\AppData\Local\Temp\ipykernel_4904\3979554078.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1["ship-postal-code"])
# <Axes: xlabel='ship-postal-code', ylabel='Density'>
